# %%
import numpy as np
import pandas as pd

# %%
paitents=pd.read_csv('state_wise_daily.csv')

# %%
paitents['Status'].value_counts()
# Out:
# Status
# Confirmed    597
# Recovered    597
# Deceased     597
# Name: count, dtype: int64

# %%
total_cases=paitents.shape[0]
Active=paitents[paitents["Status"]=="Confirmed"].shape[0]
recovered=paitents[paitents["Status"]=="Recovered"].shape[0]
deaths=paitents[paitents['Status']=='Deceased'].shape[0]

# %%
Active
# Out:
# 597
